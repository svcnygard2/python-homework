# %%
# -*- coding: utf-8 -*-
"""Student Do: Budget Analysis.

This script will use the Pathlib library to set the file path,
use the csv library to read in the file, and iterate over each
row of the file to calculate Profit/Loss Change average, Maximum Profits, and Minimum Losses.
"""

# Import the pathlib and csv library
from pathlib import Path
import csv

# Set the file path
csvpath = Path('budget_data.csv')

# Initialize list of records
records = []

# Open the csv file as an object
with open(csvpath, 'r') as csvfile:

    # Pass in the csv file to the csv.reader() function
    # (with ',' as the delmiter/separator) and return the csvreader object
    csvreader = csv.reader(csvfile, delimiter=',')

    # Read the header row first (skip this step if there is no header)
    csv_header = next(csvreader)
    # Print the header
    print(csv_header)

    # Append the column 'pnl_change' to the header
    csv_header.append("pnl_change")
    # Append the header to the list of records
    records.append(csv_header)

    
    # Read each row of data after the header
    for row in csvreader:
        # Print the row
        print(row)
    

# Open the file in "read" mode ('r') and
# store the contents in the variable 'file'
with open(file, 'r') as file:
    # Parse the file line by line
    for line in file:

        # Convert the number in the csv file from string to float
        number = float(line)

        # Sum the total and count of the numbers in the csv file
        pnl += number
        date += 1

        
# Calculate the average
daily_average = customer_total / day_count
print(f"daily_average: {daily_average}")
        
        
# Print out pnl_total and date_count
print("Financial Analysis")
print("-----------------------")
print(f"Total Months: {date_count}")
print(f"Total: {pnl_total}")
print(f"Average Change: {date_average}")


# Set output file name
output_path = 'output.txt'

# Open the output path as a file object
with open(output_path, 'w') as file:
    # Write daily_average to the output file, convert to string
    file.write(f"Greatest Increase in Profits: {customer_total} customers over the course of {day_count} days.\n")
    file.write(f"Greatest Decrease in Profts: {daily_average} customers per day.")
       

# Set the path for the output.csv
output = Path("output.csv")

# Open the output path as a file and pass into the 'csv.writer()' function
# Set the delimiter/separater as a ','
with open(output, 'w') as csvfile:
    csvwriter = csv.writer(csvfile, delimiter=',')

    # Loop through the list of records and write every record to the
    # output csv file
    for record in records:
        csvwriter.writerow(record)

# %%
# Prints out 0,1,2,3,4

count = 0
while count < 6:
    print(count)
    count += 1  # This is the same as count = count + 1
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
import csv

count_month=0
total_pnl=0
average_change=0
minimum=0
maximum=0

reader=csv.DictReader(open("budget_data.csv", "r"))
dict_list = []
for line in reader:
    dict_list.append(line)

for date, pnl in dict_list:
    print(pnl)

    
    
    
#for row in csv_file:
    #total_pnl+=row
    #count_month+=1
    #print(row)
    
#if minimum==0:
    #minimum=



    
    
    
print("Financial Analysis")
print("----------------------------")
print(f"Total Months: {count_month}")
print(f"Total: {total_pnl}")
print(f"Average Change: {average_change}")
#print(f"Greatest Increase in Profits: {}")
#print(f"Greatest Decrease in Profits: {}")
# Out:
# Profit/Losses
# Profit/Losses
# Profit/Losses
# Profit/Losses
# Profit/Losses
# Profit/Losses
# Profit/Losses
# Profit/Losses
# Profit/Losses
# Profit/Losses
# Profit/Losses
# Profit/Losses
# Profit/Losses
# Profit/Losses
# Profit/Losses
# Profit/Losses
# Profit/Losses
# Profit/Losses
# Profit/Losses
# Profit/Losses
# Profit/Losses
# Profit/Losses
# Profit/Losses
# Profit/Losses
# Profit/Losses
# Profit/Losses
# Profit/Losses
# Profit/Losses
# Profit/Losses
# Profit/Losses
# Profit/Losses
# Profit/Losses
# Profit/Losses
# Profit/Losses
# Profit/Losses
# Profit/Losses
# Profit/Losses
# Profit/Losses
# Profit/Losses
# Profit/Losses
# Profit/Losses
# Profit/Losses
# Profit/Losses
# Profit/Losses
# Profit/Losses
# Profit/Losses
# Profit/Losses
# Profit/Losses
# Profit/Losses
# Profit/Losses
# Profit/Losses
# Profit/Losses
# Profit/Losses
# Profit/Losses
# Profit/Losses
# Profit/Losses
# Profit/Losses
# Profit/Losses
# Profit/Losses
# Profit/Losses
# Profit/Losses
# Profit/Losses
# ...

# %%
import csv

count_month=0
total_pnl=0
average_change=0
minimum=0
maximum=0

with open("budget_data.csv", 'r') as budget_data:
    pnl = csv.DictReader(budget_data)
    for row in pnl:
        integer = float(row["Profit/Losses"])

reader=csv.DictReader(open("budget_data.csv", "r"))
dict_list = []
for line in reader:
    dict_list.append(line)



#for integer in pnl:
print(integer)
# Out:
# 671099.0

# %%
import csv
with open("budget_data.csv", 'r') as budget_data:
    reader = csv.DictReader(budget_data)
    for row in reader:
        integer = int(row["Profit/Losses"])
print(row["Profit/Losses"])
# Out:
# 671099

# %%
#import correct library
import csv
from pathlib import Path

# %%
#declare variables
count_month=0
total_pnl=0
average_change=0
minimum=0
maximum=0
pnl_change=0
pnl_prior=0

new_path=Path("budget_data.csv")

#opens and reads the csv file seperate the values with a ",".
with open(new_path) as csv_file:
    next(csv_file)
    csv_reader = csv.reader(csv_file, delimiter=',')

#defines both columns as "date" and "pnl"
    for data in csv_reader:
        date = data[0]
        pnl = float(data[1])
        
        pnl_change = pnl_prior - pnl
        pnl_prior = pnl
        total_pnl += pnl
        count_month += 1 
        
        if minimum == 0:
            minimum = pnl_change
        elif pnl_change < minimum:
            minimum = pnl_change
        elif pnl_change > maximum:
            maximum = pnl_change
            
    average_change = round(pnl_change / 85, 2)

    
    
#Print final result.        
print("Financial Analysis")
print("----------------------------")
print(f"Total Months: {count_month}")
print(f"Total: ${total_pnl}")
print(f"Average Change: ${average_change}")
print(f"Greatest Increase in Profits: (${maximum})")
print(f"Greatest Decrease in Profits: (${minimum})")
# Out:
# -532869.0
# Financial Analysis
# ----------------------------
# Total Months: 86
# Total: $38382578.0
# Average Change: $-6269.05
# Greatest Increase in Profits: ($2196167.0)
# Greatest Decrease in Profits: ($-1926159.0)
